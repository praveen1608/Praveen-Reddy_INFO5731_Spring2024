# %% [markdown]
# <a href="https://colab.research.google.com/github/praveen1608/Praveen-Reddy_INFO5731_Spring2024/blob/main/Kadasani_PraveenReddy_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Your code here
# (2) I'm doing 2 sub question, collecting 1000 reviews of a movie "Killers of the Flower Moon".

import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the IMDb page for the movie "Killers of the Flower Moon"
url = "https://www.imdb.com/title/tt5537002/reviews/?ref_=tt_ov_rt"

# Function to scrape user reviews
def scrape_imdb_reviews(url, num_reviews=1000):
    reviews = []
    page = 1

    while len(reviews) < num_reviews:
        page_url = f"{url}?sort=helpfulnessScore&dir=desc&ratingFilter=0&spoiler=hide&ref_=tt_ov_rt&page={page}"
        response = requests.get(page_url)
        soup = BeautifulSoup(response.text, "html.parser")
        user_reviews = soup.find_all("div", class_="text show-more__control")

        for review in user_reviews:
            text = review.get_text(strip=True)
            reviews.append(text)

        page += 1

    return reviews[:num_reviews]

# Movie name
movie_name = "Killers of the Flower Moon"

# Scrape reviews
reviews = scrape_imdb_reviews(url)

# Creating a DataFrame
data = pd.DataFrame(reviews, columns=["User Reviews"])

# Saving the data to a CSV file
csv_movies = f"{movie_name}_user_reviews.csv"
data.to_csv(csv_movies, index=False)
print(f"Collected {len(reviews)} user reviews and saved to {csv_movies}")



# Read the CSV file into a DataFrame
data = pd.read_csv(csv_movies)

# Print the top five rows
print(data.head())

# Print the bottom five rows
print(data.tail())
# Out:
# Collected 1000 user reviews and saved to Killers of the Flower Moon_user_reviews.csv
#                                         User Reviews
# 0  "Killers of the Flower Moon" is a Western crim...
# 1  Some films warrant long runtimes. Epics like '...
# 2  Martin Scorsese follows up his sloppy The Iris...
# 3  Obviously this isn't bad. It's from an amazing...
# 4  I'm not a die-hard Martin Scorsese fan. I have...
#                                           User Reviews
# 995  This film probably is enjoyed by a certain aud...
# 996  I didn't mind the length. Most of the time wit...
# 997  This is what cinema is all about, a wonderful ...
# 998  Sorry to say that this was far too long for th...
# 999  I'll start off by saying that I wanted to be p...

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Download NLTK data (stopwords and lemmatization data)
nltk.download('stopwords')
nltk.download('wordnet')

# Load the CSV file with user reviews
df = pd.read_csv(csv_movies)

# Define functions for text cleaning
def clean_text(text):
    # Removing special characters and punctuations
    text = ''.join([char for char in text if char.isalnum() or char.isspace()])

    # Removing numbers
    text = ''.join([char for char in text if not char.isdigit()])

    # Lowercase the text
    text = text.lower()

    return text

def remove_stopwords(text):  #(4) stopwords
    stop_words = set(stopwords.words("english"))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

def stem_text(text):   #(5) stemming
    stemmer = PorterStemmer()
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    return ' '.join(words)

def lemmatize_text(text):  #(6) lemmatization
    lemmatizer = WordNetLemmatizer()
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

# Apply the cleaning functions to the "User Reviews" column
df['Cleaned Reviews'] = df['User Reviews'].apply(clean_text)
df['Cleaned Reviews'] = df['Cleaned Reviews'].apply(remove_stopwords)
df['Cleaned Reviews'] = df['Cleaned Reviews'].apply(stem_text)
df['Cleaned Reviews'] = df['Cleaned Reviews'].apply(lemmatize_text)


# Update the existing CSV file with the new column
df.to_csv(csv_movies, index=False)
print(f"Cleaned data updated in {csv_movies}")


# Read the CSV file into a DataFrame
data = pd.read_csv(csv_movies)

# Print the top five rows
print(data.head())

# Print the bottom five rows
print(data.tail())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Cleaned data updated in Killers of the Flower Moon_user_reviews.csv
#                                         User Reviews  \
# 0  "Killers of the Flower Moon" is a Western crim...
# 1  Some films warrant long runtimes. Epics like '...
# 2  Martin Scorsese follows up his sloppy The Iris...
# 3  Obviously this isn't bad. It's from an amazing...
# 4  I'm not a die-hard Martin Scorsese fan. I have...
#
#                                      Cleaned Reviews
# 0  killer flower moon western crime drama film co...
# 1  film warrant long runtim epic like lawrenc ara...
# 2  martin scorses follow sloppi irishman anoth ex...
# 3  obvious isnt bad amaz director interest stori ...
# 4  im diehard martin scorses fan deep appreci mov...
#                                           User Reviews  \
# 995  This film probably is enjoyed by a certain aud...
# 996  I didn't mind the length. Most of the time wit...
# 997  This is what cinema is all about, a wonderful ...
# 998  Sorry to say that this was far too long for th...
# 999  I'll start off by saying that I wanted to be p...
#
#                                        Cleaned Reviews
# 995  film probabl enjoy certain audienc respect eve...
# 996  didnt mind length time movi wish didnt cut muc...
# 997  cinema wonder storylin terrif act stun visuals...
# 998  sorri say far long cinema found irishman far l...
# 999  ill start say want pleasantli surpris film nev...

# %%
# downloading the csv file

from google.colab import files

files.download(csv_movies)

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here

import spacy

# Loading the cleaned data from the CSV file
df = pd.read_csv(csv_movies)

# Initialize spaCy
nlp = spacy.load("en_core_web_sm")

# Function to perform POS tagging and count POS categories
def pos_tagging(text):
    doc = nlp(text)
    pos_counts = {"Noun": 0, "Verb": 0, "Adjective": 0, "Adverb": 0}

    for token in doc:
        if token.pos_ == "NOUN":
            pos_counts["Noun"] += 1
        elif token.pos_ == "VERB":
            pos_counts["Verb"] += 1
        elif token.pos_ == "ADJ":
            pos_counts["Adjective"] += 1
        elif token.pos_ == "ADV":
            pos_counts["Adverb"] += 1

    return pos_counts


# Function to perform constituency parsing
def constituency_parsing(text):
    doc = nlp(text)
    constituency_tree = ""

    for sent in doc.sents:
        for token in sent:
            constituency_tree += f"({token.text} ({token.dep_} "
        constituency_tree += ")"

    return constituency_tree

# Function to perform dependency parsing
def dependency_parsing(text):
    doc = nlp(text)

    for sent in doc.sents:
        for token in sent:
            print(token.text, token.dep_, token.head.text)

# Function to perform Named Entity Recognition (NER)
def named_entity_recognition(text):
    doc = nlp(text)
    entities = {}

    for ent in doc.ents:
        entity_type = ent.label_
        if entity_type in entities:
            entities[entity_type] += 1
        else:
            entities[entity_type] = 1

    return entities


# Example sentence for explanation
example_sentence = df['Cleaned Reviews'][0]

#(1)Perform POS tagging and count POS categories
pos_counts = pos_tagging(example_sentence)
print("POS Tagging:", pos_counts)

#(2)Perform constituency parsing
constituency_tree = constituency_parsing(example_sentence)
print("Constituency Parsing Tree:", constituency_tree)

#(2) Perform dependency parsing
print("Dependency Parsing:")
dependency_parsing(example_sentence)

#(3)Perform Named Entity Recognition (NER)
entities = named_entity_recognition(example_sentence)
print("Named Entity Recognition:", entities)
# Out:
# POS Tagging: {'Noun': 277, 'Verb': 97, 'Adjective': 99, 'Adverb': 25}
# Constituency Parsing Tree: (killer (nsubj (flower (nsubj (moon (compound (western (amod (crime (compound (drama (compound (film (compound (cowritten (nmod (direct (amod (martin (compound (scorses (compound (base (compound (nonfict (compound (book (compound (name (compound (david (compound (grann (compound (star (compound (leonardo (compound (dicaprio (compound (robert (compound (de (compound (niro (compound (lili (compound (gladston (compound (touch (dobj (upon (prep (often (advmod (overlook (ROOT (piec (compound (american (amod (histori (nmod (best (amod (way (nmod (possibl (compound (thank (compound (talent (compound (director (compound (castin (compound (earli (compound (discoveri (amod (oil (compound (land (nsubj (belong (relcl (nativ (nmod (american (amod (osag (amod (nation (nsubj (turn (ccomp (tribe (nmod (richest (amod (peopl (compound (world (nmod (sudden (amod (acquisit (compound (wealth (compound (attract (dobj (attent (compound (white (compound (businessmen (nsubj (look (conj (seiz (compound (opportun (nsubj (steal (ccomp (much (advmod (osag (amod (tribe (compound (possibl (dobj (among (prep (group (compound (interlop (compound (ernest (amod (burkhart (compound (leonardo (compound (dicaprio (pobj (upon (prep (arriv (compound (oklahoma (compound (encourag (compound (uncl (compound (william (compound (king (compound (hale (pobj (robert (nmod (de (compound (niro (compound (marri (compound (member (appos (osag (amod (way (appos (inherit (compound (fortun (nsubj (ernest (advmod (soon (advmod (fall (conj (love (dobj (later (advmod (marri (compound (molli (compound (lili (compound (gladston (nmod (young (amod (osag (amod (woman (nsubj (strong (amod (tie (compound (famili (nmod (rich (amod (white (compound (occup (compound (nativ (compound (land (compound (continu (compound (member (compound (osag (compound (tribe (compound (repeatedli (nsubj (found (conj (murder (compound (mysteri (amod (circumst (compound (molli (compound (close (amod (famili (dobj (among (prep (promin (compound (victimson (compound (favourit (compound (thing (compound (movi (compound (addit (pobj (enjoy (compound (mean (advmod (entertain (nsubj (also (advmod (function (ccomp (great (amod (method (compound (preserv (compound (matter (compound (obscur (compound (topic (dobj (may (aux (film (aux (made (conj (releas (compound (mainstream (compound (alreadi (compound (perman (compound (preserv (compound (way (nsubj (especi (nsubj (effect (dobj (filmmak (compound (believ (compound (peopl (nsubj (made (ccomp (awar (compound (someth (dobj (may (aux (otherwis (advmod (forgotten (amod (time (compound (help (aux (maintain (advcl (relev (compound (gener (dobj (public (amod (one (nummod (event (nsubj (often (advmod (glanc (ccomp (osag (amod (indian (amod (murder (compound (seri (compound (slay (compound (wealthi (compound (member (compound (nativ (nmod (american (nmod (osag (amod (tribe (dobj (earli (nmod (th (intj (centuri (compound (howev (npadvmod (thank (ccomp (martin (compound (scorses (dobj (film (compound (killer (compound (flower (compound (moon (compound (audienc (compound (chanc (compound (educ (compound (entertain (nsubj (overlook (ccomp (histor (compound (occurr (dobj (movi (compound (provid (compound (sophist (compound (eyeopen (dobj (look (compound (america (compound (treatment (dobj (one (nummod (particular (amod (group (compound (indigen (dobj (populationmuch (appos (like (prep (scorses (pobj (best (advmod (known (amod (work (compound (film (compound (frame (appos (epic (nmod (indepth (amod (studi (nmod (dark (amod (side (appos (human (compound (natur (nsubj (watch (conj (osag (amod (tribe (nsubj (live (ccomp (harmoni (dobj (among (prep (forcibl (compound (thrust (amod (sight (compound (outsid (nmod (world (compound (oil (npadvmod (found (ccomp (land (nsubj (spite (ccomp (vast (amod (wealth (compound (accumul (amod (osag (amod (unabl (nsubj (hold (conj (back (prt (larg (compound (tide (compound (white (compound (peopl (compound (show (compound (attem ...
# Dependency Parsing:
# killer nsubj flower
# flower nsubj overlook
# moon compound film
# western amod crime
# crime compound film
# drama compound film
# film compound touch
# cowritten nmod touch
# direct amod martin
# martin compound scorses
# scorses compound book
# base compound book
# nonfict compound book
# book compound name
# name compound dicaprio
# david compound grann
# grann compound dicaprio
# star compound dicaprio
# leonardo compound dicaprio
# dicaprio compound touch
# robert compound lili
# de compound niro
# niro compound lili
# lili compound touch
# gladston compound touch
# touch dobj flower
# upon prep flower
# often advmod overlook
# overlook ROOT overlook
# piec compound way
# american amod way
# histori nmod way
# best amod way
# way nmod nation
# possibl compound land
# thank compound director
# talent compound director
# director compound land
# castin compound land
# earli compound land
# discoveri amod land
# oil compound land
# land nsubj belong
# belong relcl way
# nativ nmod nation
# american amod nation
# osag amod nation
# nation nsubj turn
# turn ccomp overlook
# tribe nmod world
# richest amod world
# peopl compound world
# world nmod wealth
# sudden amod wealth
# acquisit compound wealth
# wealth compound attract
# attract dobj turn
# attent compound businessmen
# white compound businessmen
# businessmen nsubj look
# look conj turn
# seiz compound opportun
# opportun nsubj steal
# steal ccomp look
# much advmod osag
# osag amod tribe
# tribe compound possibl
# possibl dobj steal
# among prep possibl
# group compound interlop
# interlop compound dicaprio
# ernest amod burkhart
# burkhart compound dicaprio
# leonardo compound dicaprio
# dicaprio pobj among
# upon prep steal
# arriv compound encourag
# oklahoma compound encourag
# encourag compound uncl
# uncl compound hale
# william compound king
# king compound hale
# hale pobj upon
# robert nmod member
# de compound niro
# niro compound member
# marri compound member
# member appos hale
# osag amod way
# way appos hale
# inherit compound fortun
# fortun nsubj fall
# ernest advmod fortun
# soon advmod fall
# fall conj overlook
# love dobj fall
# later advmod occup
# marri compound lili
# molli compound lili
# lili compound woman
# gladston nmod woman
# young amod woman
# osag amod woman
# woman nsubj tie
# strong amod woman
# tie compound white
# famili nmod white
# rich amod white
# white compound occup
# occup compound repeatedli
# nativ compound land
# land compound continu
# continu compound member
# member compound repeatedli
# osag compound tribe
# tribe compound repeatedli
# repeatedli nsubj found
# found conj overlook
# murder compound famili
# mysteri amod famili
# circumst compound molli
# molli compound famili
# close amod famili
# famili dobj found
# among prep famili
# promin compound victimson
# victimson compound thing
# favourit compound thing
# thing compound addit
# movi compound addit
# addit pobj among
# enjoy compound mean
# mean advmod found
# entertain nsubj function
# also advmod function
# function ccomp found
# great amod matter
# method compound matter
# preserv compound matter
# matter compound obscur
# obscur compound topic
# topic dobj function
# may aux film
# film aux overlook
# made conj overlook
# releas compound way
# mainstream compound alreadi
# alreadi compound perman
# perman compound way
# preserv compound way
# way nsubj especi
# especi nsubj made
# effect dobj especi
# filmmak compound peopl
# believ compound peopl
# peopl nsubj made
# made ccomp made
# awar compound someth
# someth dobj made
# may aux maintain
# otherwis advmod forgotten
# forgotten amod time
# time compound help
# help aux maintain
# maintain advcl made
# relev compound gener
# gener dobj maintain
# public amod one
# one nummod event
# event nsubj glanc
# often advmod glanc
# glanc ccomp maintain
# osag amod tribe
# indian amod murder
# murder compound seri
# seri compound wealthi
# slay compound wealthi
# wealthi compound member
# member compound tribe
# nativ nmod tribe
# american nmod tribe
# osag amod tribe
# tribe dobj glanc
# earli nmod howev
# th intj earli
# centuri compound howev
# howev npadvmod thank
# thank ccomp glanc
# martin compound scorses
# scorses dobj thank
# film compound killer
# killer compound moon
# flower compound moon
# moon compound entertain
# audienc compound chanc
# chanc compound entertain
# educ compound entertain
# entertain nsubj overlook
# overlook ccomp glanc
# histor compound occurr
# occurr dobj overlook
# movi compound eyeopen
# provid compound eyeopen
# sophist compound eyeopen
# eyeopen dobj occurr
# look compound treatment
# america compound treatment
# treatment dobj eyeopen
# one nummod indigen
# particular amod indigen
# group compound indigen
# indigen dobj occurr
# populationmuch appos indigen
# like prep populationmuch
# scorses pobj like
# best advmod known
# known amod frame
# work compound film
# film compound frame
# frame appos scorses
# epic nmod side
# indepth amod side
# studi nmod side
# dark amod side
# side appos frame
# human compound natur
# natur nsubj watch
# watch conj overlook
# osag amod tribe
# tribe nsubj live
# live ccomp watch
# harmoni dobj live
# among prep live
# forcibl compound outsid
# thrust amod outsid
# sight compound outsid
# outsid nmod oil
# world compound oil
# oil npadvmod found
# found ccomp maintain
# land nsubj spite
# spite ccomp found
# vast amod accumul
# wealth compound accumul
# accumul amod unabl
# osag amod unabl
# unabl nsubj hold
# hold conj found
# back prt hold
# larg compound tide
# tide compound attempt
# white compound peopl
# peopl compound attempt
# show compound attempt
# attempt nsubj steal
# steal ccomp hold
# away prt steal
# everyth nmod happi
# rightli compound tribe
# tribe compound happi
# happi nsubj exist
# exist conj overlook
# compromis amod physic
# subject amod discrimin
# frequent amod discrimin
# discrimin nmod physic
# first amod physic
# verbal amod physic
# physic nsubj see
# see conj overlook
# sinist compound plan
# plan compound hale
# william compound king
# king compound hale
# hale nsubj come
# come nsubj play
# play ccomp see
# marri compound nephew
# nephew dobj play
# ernest prep play
# osag amod way
# way pobj ernest
# pilfer conj play
# rich amod time
# time npadvmod pilfer
# right nsubj make
# make conj overlook
# scheme nsubj watch
# intrigu nsubj watch
# watch ccomp make
# patienc amod requir
# requir nsubj pull
# pull ccomp watch
# ethic amod ramif
# ramif compound filmmak
# result compound filmmak
# filmmak dobj pull
# like prep filmmak
# scorses pobj like
# could aux explor
# explor nsubj remain
# topic dobj explor
# like prep topic
# complex amod style
# style pobj like
# remain conj overlook
# timeless compound everaddit
# everaddit attr remain
# almost advmod scorses
# scorses advcl remain
# visual amod director
# trademark compound director
# director dobj scorses
# full amod display
# display compound immers
# wideopen compound immers
# cinematographi compound immers
# design compound immers
# immers appos director
# audienc compound charact
# world compound creativ
# america compound creativ
# creativ compound frame
# frame compound charact
# charact compound shot
# shot conj remain
# give xcomp shot
# certain amod scene
# perspect compound scene
# scene dative give
# one nummod scene
# particular amod one
# stood amod convers
# convers compound busi
# ernest compound busi
# william compound busi
# discus compound busi
# busi compound regard
# regard nsubj see
# osag amod regard
# see ccomp overlook
# two nummod futur
# seat nmod futur
# insid amod futur
# darkli amod futur
# lit amod room
# room compound discus
# discus compound type
# type compound futur
# futur compound lie
# lie nsubj entir
# ahead advmod entir
# entir ccomp see
# tribe compound choos
# ernest compound choos
# choos nsubj remain
# remain conj overlook
# loyal amod wife
# osag amod wife
# wife compound uncl
# molli compound uncl
# uncl compound nephew
# william compound nephew
# remind compound nephew
# nephew compound import
# import compound reason
# reason nsubj make
# marri nmod place
# first amod place
# place nsubj scorses
# scorses relcl reason
# place dobj scorses
# charact compound way
# way npadvmod scorses
# make advcl remain
# look ccomp make
# place nsubj look
# insid nmod room
# singl amod room
# bright amod spot
# spot nmod room
# dark amod room
# room compound dark
# dark nsubj surround
# surround ROOT surround
# two nummod visual
# liken amod visual
# perfect amod visual
# visual dobj surround
# represent conj surround
# true amod suppos
# intent amod suppos
# suppos dobj represent
# bright amod suppos
# focus compound presenc
# actual amod metaphor
# metaphor compound presenc
# taint compound presenc
# presenc dobj surround
# everyth prep surround
# osag amod film
# creat compound pointdu
# pointdu compound scale
# scale compound film
# theme compound film
# plot compound film
# film pobj everyth
# right nsubj earn
# earn advcl surround
# long amod runtim
# runtim dobj earn
# almost advmod three
# three nummod hour
# half quantmod three
# hour compound minut
# minut compound mani
# total amod mani
# mani nsubj differ
# differ conj surround
# facet compound explor
# explor compound action
# charact compound action
# action compound result
# result compound consequ
# consequ nsubj make
# make ccomp differ
# compel nsubj view
# view amod person
# experi amod person
# person nsubj think
# think ccomp make
# made ccomp think
# film compound interest
# interest compound watch
# watch dobj made
# i nsubjpass entir
# m auxpass entir
# entir ccomp said
# sure advmod entir
# said ROOT said
# casual amod pace
# viewer amod film
# film compound pace
# pace compound intent
# intent nsubj build
# slow amod mean
# mean amod build
# build compound work
# tension compound work
# air compound believ
# believ compound work
# work nsubj effect
# rather advmod effect
# effect ccomp said
# minim compound score
# music compound score
# score compound use
# use compound showcas
# method compound showcas
# showcas compound view
# realist amod point
# point compound view
# view compound requir
# scene nmod requir
# raw amod emot
# emot appos scene
# word compound film
# film compound requir
# requir compound mind
# patienc compound attent
# attent compound mind
# mind nsubj anybodi
# someth compound reward
# greatli compound reward
# reward nsubj anybodi
# anybodi ccomp effect
# manag compound display
# display compound scorses
# virtu compound effect
# effect compound scorses
# scorses nsubj made
# made conj effect
# film compound heavili
# heavili nsubj reliant
# reliant ccomp made
# atmospher advmod deliv
# rather advmod frequent
# frequent amod action
# action compound blockbustersin
# hollywood compound blockbustersin
# blockbustersin nmod director
# sixth amod director
# collabor compound legendari
# legendari compound director
# director compound dicaprio
# leonardo compound dicaprio
# dicaprio compound deliv
# deliv dobj reliant
# yet advmod made
# anoth conj made
# memor compound perform
# perform compound role
# role nmod burkhart
# ernest amod burkhart
# burkhart dobj anoth
# make advcl effect
# dicaprio compound charact
# charact nsubj intrigu
# intrigu nsubj torn
# indecis nsubj torn
# natur npadvmod torn
# torn amod wife
# support nmod wife
# white amod famili
# famili nmod wife
# osag amod wife
# wife nsubj molli
# molli nsubj loyalti
# one nummod hand
# hand compound loyalti
# ernest compound loyalti
# loyalti nsubj made
# toward prep loyalti
# birth compound famili
# famili pobj toward
# made ccomp make
# go xcomp made
# ahead advmod go
# uncl amod idea
# idea npadvmod go
# first compound molli
# place compound molli
# hand compound fall
# truli compound fall
# fall compound molli
# molli nsubj bring
# can aux bring
# not neg bring
# bring ccomp make
# end dobj bring
# along prep bring
# entir amod signatur
# tribe compound dicaprio
# dicaprio compound signatur
# display compound signatur
# signatur compound altern
# rang compound altern
# emot nmod altern
# altern nmod man
# strong amod man
# famili amod man
# man compound submiss
# submiss pobj along
# weakl amod bid
# uncl amod bid
# bid nsubj pull
# pull advcl bring
# quit compound work
# effectivelyaft compound work
# work nmod step
# ten nummod film
# film nmod step
# togeth compound niro
# robert compound niro
# de compound niro
# niro appos film
# step dobj pull
# back advmod step
# usual amod scorses
# spot compound scorses
# scorses nsubj lead
# lead conj effect
# support compound role
# role compound hale
# william compound king
# king compound hale
# hale dobj lead
# essenti conj effect
# main amod antagonist
# antagonist compound stori
# stori compound determin
# hale compound man
# man compound determin
# determin compound way
# weasel compound way
# way compound wealth
# wealth dobj essenti
# regardless advmod essenti
# whether mark earn
# truli nsubj earn
# earn advcl effect
# intent compound malici
# malici nsubj meant
# meant ccomp earn
# serv compound person
# person nsubj gain
# gain ccomp meant
# littl compound regard
# regard dobj gain
# wellb advcl said
# other amod bibl
# even advmod nephew
# nephew nmod trait
# consid advmod worst
# worst amod trait
# charact compound trait
# trait compound bibl
# believ compound bibl
# action compound bibl
# justifi compound bibl
# bibl nsubj say
# say ccomp said
# spread amod word
# word npadvmod claim
# god nsubj claim
# claim ccomp say
# god nsubj want
# want ccomp claim
# particip compound genocid
# genocid nsubj entir
# entir ccomp want
# race compound peopl
# peopl dobj entir
# noth nmod evil
# short amod evil
# evil amod point
# demonstr compound numer
# numer compound point
# point dobj entir
# throughout prep entir
# film compound role
# role pobj throughout
# like prep role
# perfect amod actor
# actor pobj like
# like prep actor
# robert compound niro
# de compound niro
# niro pobj like
# better amod director
# director appos niro
# show compound standout
# world compound film
# martin nmod film
# scorsesehowev compound film
# film compound standout
# true amod standout
# standout nsubj lili
# would aux lili
# lili ccomp say
# gladston compound molli
# molli compound stori
# truli compound stori
# heart compound stori
# soul compound stori
# stori compound woman
# woman compound experienc
# experienc dobj lili
# much amod life
# pain compound heartbreak
# heartbreak compound life
# life dobj lili
# whether mark rel
# physic amod rel
# ailment nmod rel
# sudden amod rel
# death compound rel
# rel nsubj remain
# yet cc rel
# despit compound hardship
# hardship compound molli
# molli nsubj remain
# remain ccomp said
# steadfast acomp remain
# ever advmod steadfast
# choos compound wife
# love compound wife
# wife compound care
# husband compound care
# care compound mother
# mother compound molli
# young amod child
# child compound molli
# molli nsubj essenti
# essenti nsubj sold
# repres nsubj posit
# posit ccomp essenti
# valu compound tribe
# tribe compound uphold
# uphold ccomp essenti
# among prep uphold
# last amod famili
# famili pobj among
# has aux sold
# nt neg sold
# complet nsubj sold
# sold ccomp scorses
# ideal amod defin
# rich amod defin
# lifestyl compound defin
# easili compound career
# career compound defin
# defin compound role
# role compound star
# gladston compound potenti
# certainli compound potenti
# potenti nsubj star
# noteworthi nsubj star
# star advcl sold
# one nummod star
# dayfor dative sold
# american compound buff
# histori compound buff
# buff compound scorses
# martin nsubj scorses
# scorses nsubj say
# fan compound killer
# killer compound moon
# flower compound moon
# moon nsubj repres
# repres ccomp scorses
# fascin nsubj look
# look ccomp repres
# best amod world
# world nsubj bring
# bring ccomp repres
# attent dobj bring
# often advmod neglect
# neglect advmod scorses
# histor compound issu
# issu nsubj use
# use conj scorses
# anoth amod addit
# wellcraft compound addit
# cinemat compound addit
# addit compound librari
# belov compound filmmak
# filmmak compound veteran
# veteran compound librari
# librari nsubj mention
# mention conj scorses
# previous amod gener
# nice amod know
# know compound stori
# stori compound effect
# effect nmod gener
# preserv nmod medium
# medium nmod film
# film nmod gener
# mean amod gener
# futur compound gener
# gener compound watch
# abl compound watch
# watch ccomp mention
# back advmod watch
# learn compound event
# horrif compound event
# event nsubj took
# took ccomp mention
# place compound time
# time compound classic
# period compound classic
# classic nsubj say
# say ROOT say
# goe nsubj learn
# do aux learn
# nt neg learn
# learn ccomp say
# histori compound doom
# doom nsubj repeat
# repeat ccomp learn
# iti compound rate
# rate dobj repeat
# solid ccomp say
# Named Entity Recognition: {'PERSON': 25, 'NORP': 5, 'GPE': 6, 'TIME': 2, 'CARDINAL': 6, 'ORG': 4, 'ORDINAL': 4}

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %% [markdown]
# This assignment was great, it helps in recollecting the topics that we learnt in the class. By doing this in practical it helps in remembering the topics very clearly. First I thought of collecting reviews from amazon, but endup in choosing the movie reviews. There are not much challenges I faced this assignment, but worked on csv files and how to download it and store it etc. I really enjoyed in text cleaning part, like I used to observe the results after the step and how the effects were after conducting a particular step. The time provided for the assignment is perfectly sufficient. Students with more than 9 credits may have faced some time issues, but it was sufficient.
